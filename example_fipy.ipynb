# %%
import numpy as np
from scipy.spatial import Delaunay
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib as mpl
dpi = 400
mpl.rcParams['figure.dpi']= dpi

font = {'family' : 'normal',
           'size'   : 2}

rc('font', **font)

# %%
x = np.linspace(0,1,10)
y = np.linspace(0,1,10)

points = np.zeros([len(x)*len(y), 2])
k = 0
for i in x:
    for j in y:
        points[k,1] = j
        points[k,0] = i
        k += 1

# %%
tri = Delaunay(points)


# This gives for triangle i the number of points 
# in the point array which build their borders
i = 69 # 25 26 36
print("corners of i", tri.simplices[i])

# This gives numbers of the neighboring triangles of triangle i
i = 69 # 140 71 68
print("neigbors of i", tri.neighbors[i])
# Out:
# corners of i [61 70 71]
# neigbors of i [63 72 68]

# %%
plt.triplot(points[:,0], points[:,1], tri.simplices)

plt.plot(points[:,0], points[:,1], 'o')
for j, p in enumerate(points):

    plt.text(p[0], p[1], j, ha='right') # label the points

for j, s in enumerate(tri.simplices):

    p = points[s].mean(axis=0)

    plt.text(p[0], p[1], '#%d' % j, ha='center') # label triangles

plt.xlim(-0.5, 1.5); plt.ylim(-0.5, 1.5)
mpl.rc("savefig", dpi=dpi)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import numpy as np
import sys
np.set_printoptions(threshold=sys.maxsize)
from scipy.ndimage.interpolation import zoom
arr = np.random.uniform(size=(4,4))
arr = zoom(arr, 8)
len(arr)
# Out:
# 32

# %%
a = np.round(np.random.randn(4,4) * 10, decimals=0)
b = np.roll(a,-1,axis=1)

print(a)
print(b)
# Out:
# [[ -9.   5.  -1.   1.]
#  [ -0.  29. -15.   8.]
#  [-12. -10.   8.   4.]
#  [  3.  11. -27.   2.]]
# [[  5.  -1.   1.  -9.]
#  [ 29. -15.   8.  -0.]
#  [-10.   8.   4. -12.]
#  [ 11. -27.   2.   3.]]

# %%
def get_tangent(x,y,dxdy, width=0.1):
    x_tan = np.linspace(x-width,x+width,10)
    print(x_tan)
    y_tan = dxdy*(x_tan - np.ones([1,10])[0]*x) + np.ones([1, 10])[0]*y
    print(y_tan)
    return [x_tan, y_tan]

plt.scatter([1,2], [1,0.5])
tan1 = get_tangent(1,1,-2)
tan2 = get_tangent(2,0.5,1)
plt.plot(tan1[0],tan1[1], 'r')
plt.plot(tan2[0],tan2[1])
# Out:
# [0.9        0.92222222 0.94444444 0.96666667 0.98888889 1.01111111
#  1.03333333 1.05555556 1.07777778 1.1       ]
# [1.2        1.15555556 1.11111111 1.06666667 1.02222222 0.97777778
#  0.93333333 0.88888889 0.84444444 0.8       ]
# [1.9        1.92222222 1.94444444 1.96666667 1.98888889 2.01111111
#  2.03333333 2.05555556 2.07777778 2.1       ]
# [0.4        0.42222222 0.44444444 0.46666667 0.48888889 0.51111111
#  0.53333333 0.55555556 0.57777778 0.6       ]
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1331: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
